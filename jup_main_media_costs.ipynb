# %%
import os

from time import sleep
import config
import config_media_costs
from config_search_funcs import get_subbrand_id_str
from media_costs import get_media_costs_report, get_mon_num_from_date
from create_dicts_adex import create_adex_tables, download_adex_default_dicts, update_media_ads_dict, update_another_dicts, update_list_dicts, create_adex_views
from google_connector import append_ads_to_google


subbrand_id_str = get_subbrand_id_str(mon_num='360')
special_ad_filter = f'{config_media_costs.main_filter_str} AND t10.sbid in ({subbrand_id_str})'

start_date = '2024-02-01' # если дата начала НЕ указана, то start_date = Сегодня минус 3 дня минус 17 дней
end_date = '2025-03-02' #- ВКЛЮЧИТЕЛЬНО / если дата окончания НЕ указана, то end_date = Сегодня минус 3 дня

flag='regular' #first / regular
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно

# %%
# создаем пустые таблицы Фактов и Справочники
# Заполняем справоники по умолчанию данными config_media_costs.adex_defult_dicts
# Company / Ad_type / EState / 
if flag=='first':
    # создаем все пустые таблицы
    create_adex_tables()
    sleep(10)
    # наполняем данными справочники, которые НЕ обновляются
    download_adex_default_dicts()
    sleep(10)
    # создаем Представления
    create_adex_views()

# забираем статистику по каждому Медиа за указанный период
for key, value in config.media_type_dict.items():
    get_media_costs_report(start_date=start_date, end_date=end_date, media_type=key, flag=flag, main_filter=special_ad_filter)
# Out:
# Скрипт запущен 2025-04-25 17:05:03.995942
#
# **************************************************
# Удалем строки из таблицы: media_tv_costs по условию: mon_num >= 409 and mon_num <= 422
#
# Все ок. Подключились!
# Строки с условием WHERE mon_num >= 409 and mon_num <= 422 удалены из Таблицы: media_tv_costs в БД: test_media_costs
# ##########
#
#
# Загружаем отчет за период 2024-02-01 - 2025-03-02. Общее количество месяцев: 2
# **************************************************
#
#
# ==========Загружаем 2024-02-01. Статистика по tv
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:18.280810
# Данные добавлены в БД: test_media_costs, таблица: media_tv_costs
# Скрипт отработал 2025-04-25 17:05:20.994705
# Время выполнения задачи: 0:00:02.713895
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
#
# ==========Загружаем 2024-03-01. Статистика по tv
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:33.546618
# Данные добавлены в БД: test_media_costs, таблица: media_tv_costs
# Скрипт отработал 2025-04-25 17:05:36.674139
# Время выполнения задачи: 0:00:03.127521
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Скрипт запущен 2025-04-25 17:05:36.709150
#
# **************************************************
# Удалем строки из таблицы: media_ra_costs по условию: mon_num >= 409 and mon_num <= 422
#
# Все ок. Подключились!
# Таблицы media_ra_costs не существует в БД test_media_costs
#
#
# Загружаем отчет за период 2024-02-01 - 2025-03-02. Общее количество месяцев: 2
# **************************************************
#
#
# ==========Загружаем 2024-02-01. Статистика по ra
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:39.496113
# Данные добавлены в БД: test_media_costs, таблица: media_radio_costs
# Скрипт отработал 2025-04-25 17:05:39.559985
# Время выполнения задачи: 0:00:00.063872
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
#
# ==========Загружаем 2024-03-01. Статистика по ra
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:42.160455
# Данные добавлены в БД: test_media_costs, таблица: media_radio_costs
# Скрипт отработал 2025-04-25 17:05:42.222774
# Время выполнения задачи: 0:00:00.062319
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Скрипт запущен 2025-04-25 17:05:42.222774
#
# **************************************************
# Удалем строки из таблицы: media_od_costs по условию: mon_num >= 409 and mon_num <= 422
#
# Все ок. Подключились!
# Таблицы media_od_costs не существует в БД test_media_costs
#
#
# Загружаем отчет за период 2024-02-01 - 2025-03-02. Общее количество месяцев: 2
# **************************************************
#
#
# ==========Загружаем 2024-02-01. Статистика по od
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:44.082697
# Данные добавлены в БД: test_media_costs, таблица: media_outdoor_costs
# Скрипт отработал 2025-04-25 17:05:44.192340
# Время выполнения задачи: 0:00:00.109643
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
#
# ==========Загружаем 2024-03-01. Статистика по od
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:46.412772
# Данные добавлены в БД: test_media_costs, таблица: media_outdoor_costs
# Скрипт отработал 2025-04-25 17:05:46.548021
# Время выполнения задачи: 0:00:00.135249
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Скрипт запущен 2025-04-25 17:05:46.548021
#
# **************************************************
# Удалем строки из таблицы: media_pr_costs по условию: mon_num >= 409 and mon_num <= 422
#
# Все ок. Подключились!
# Таблицы media_pr_costs не существует в БД test_media_costs
#
#
# Загружаем отчет за период 2024-02-01 - 2025-03-02. Общее количество месяцев: 2
# **************************************************
#
#
# ==========Загружаем 2024-02-01. Статистика по pr
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:49.034779
# Данные добавлены в БД: test_media_costs, таблица: media_press_costs
# Скрипт отработал 2025-04-25 17:05:49.069041
# Время выполнения задачи: 0:00:00.034262
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
#
# ==========Загружаем 2024-03-01. Статистика по pr
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:50.651956
# Данные добавлены в БД: test_media_costs, таблица: media_press_costs
# Скрипт отработал 2025-04-25 17:05:50.673302
# Время выполнения задачи: 0:00:00.021346
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################

# %%
for media_type, media_type_long in config.media_type_dict.items():
    update_media_ads_dict(media_type)
    update_another_dicts(media_type)
    update_list_dicts(media_type)
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:53.852270
# Данные добавлены в БД: test_media_costs, таблица: adex_ad_dict_list_tv
# Скрипт отработал 2025-04-25 17:05:53.888276
# Время выполнения задачи: 0:00:00.036006
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:53.959816
# Данные добавлены в БД: test_media_costs, таблица: adex_audio_slogan_dict_tv
# Скрипт отработал 2025-04-25 17:05:53.971832
# Время выполнения задачи: 0:00:00.012016
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:54.017924
# Данные добавлены в БД: test_media_costs, таблица: adex_video_slogan_dict_tv
# Скрипт отработал 2025-04-25 17:05:54.030923
# Время выполнения задачи: 0:00:00.012999
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:54.080044
# Данные добавлены в БД: test_media_costs, таблица: adex_advertiser_list_dict
# Скрипт отработал 2025-04-25 17:05:54.093052
# Время выполнения задачи: 0:00:00.013008
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:54.147207
# Данные добавлены в БД: test_media_costs, таблица: adex_brand_list_dict
# Скрипт отработал 2025-04-25 17:05:54.160206
# Время выполнения задачи: 0:00:00.012999
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:54.201824
# Данные добавлены в БД: test_media_costs, таблица: adex_subbrand_list_dict
# Скрипт отработал 2025-04-25 17:05:54.216846
# Время выполнения задачи: 0:00:00.015022
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:54.266665
# Данные добавлены в БД: test_media_costs, таблица: adex_model_list_dict
# Скрипт отработал 2025-04-25 17:05:54.296358
# Время выполнения задачи: 0:00:00.029693
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:54.343246
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list2_dict
# Скрипт отработал 2025-04-25 17:05:54.358970
# Время выполнения задачи: 0:00:00.015724
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:54.405843
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list3_dict
# Скрипт отработал 2025-04-25 17:05:54.421395
# Время выполнения задачи: 0:00:00.015552
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:05:54.486122
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list4_dict
# Скрипт отработал 2025-04-25 17:05:54.500116
# Время выполнения задачи: 0:00:00.013994
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:01.108493
# Данные добавлены в БД: test_media_costs, таблица: adex_ad_dict_list_radio
# Скрипт отработал 2025-04-25 17:06:01.139274
# Время выполнения задачи: 0:00:00.030781
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:01.170505
# Данные добавлены в БД: test_media_costs, таблица: adex_advertiser_list_dict
# Скрипт отработал 2025-04-25 17:06:01.186188
# Время выполнения задачи: 0:00:00.015683
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:01.233001
# Данные добавлены в БД: test_media_costs, таблица: adex_brand_list_dict
# Скрипт отработал 2025-04-25 17:06:01.233001
# Время выполнения задачи: 0:00:00
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:01.281640
# Данные добавлены в БД: test_media_costs, таблица: adex_subbrand_list_dict
# Скрипт отработал 2025-04-25 17:06:01.296407
# Время выполнения задачи: 0:00:00.014767
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:01.343273
# Данные добавлены в БД: test_media_costs, таблица: adex_model_list_dict
# Скрипт отработал 2025-04-25 17:06:01.359105
# Время выполнения задачи: 0:00:00.015832
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:01.390384
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list2_dict
# Скрипт отработал 2025-04-25 17:06:01.406081
# Время выполнения задачи: 0:00:00.015697
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:01.437317
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list3_dict
# Скрипт отработал 2025-04-25 17:06:01.452934
# Время выполнения задачи: 0:00:00.015617
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:01.500427
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list4_dict
# Скрипт отработал 2025-04-25 17:06:01.516564
# Время выполнения задачи: 0:00:00.016137
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:08.782115
# Данные добавлены в БД: test_media_costs, таблица: adex_ad_dict_list_outdoor
# Скрипт отработал 2025-04-25 17:06:08.829279
# Время выполнения задачи: 0:00:00.047164
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:08.876527
# Данные добавлены в БД: test_media_costs, таблица: adex_advertiser_list_dict
# Скрипт отработал 2025-04-25 17:06:08.892195
# Время выполнения задачи: 0:00:00.015668
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:08.939654
# Данные добавлены в БД: test_media_costs, таблица: adex_brand_list_dict
# Скрипт отработал 2025-04-25 17:06:08.939654
# Время выполнения задачи: 0:00:00
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:09.018278
# Данные добавлены в БД: test_media_costs, таблица: adex_subbrand_list_dict
# Скрипт отработал 2025-04-25 17:06:09.033921
# Время выполнения задачи: 0:00:00.015643
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:09.096546
# Данные добавлены в БД: test_media_costs, таблица: adex_model_list_dict
# Скрипт отработал 2025-04-25 17:06:09.113170
# Время выполнения задачи: 0:00:00.016624
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:09.143992
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list2_dict
# Скрипт отработал 2025-04-25 17:06:09.167445
# Время выполнения задачи: 0:00:00.023453
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:09.208316
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list3_dict
# Скрипт отработал 2025-04-25 17:06:09.223326
# Время выполнения задачи: 0:00:00.015010
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:09.270284
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list4_dict
# Скрипт отработал 2025-04-25 17:06:09.285926
# Время выполнения задачи: 0:00:00.015642
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:12.092464
# Данные добавлены в БД: test_media_costs, таблица: adex_ad_dict_list_press
# Скрипт отработал 2025-04-25 17:06:12.128967
# Время выполнения задачи: 0:00:00.036503
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:12.155707
# Данные добавлены в БД: test_media_costs, таблица: adex_advertiser_list_dict
# Скрипт отработал 2025-04-25 17:06:12.171266
# Время выполнения задачи: 0:00:00.015559
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:12.218144
# Данные добавлены в БД: test_media_costs, таблица: adex_brand_list_dict
# Скрипт отработал 2025-04-25 17:06:12.233828
# Время выполнения задачи: 0:00:00.015684
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:12.280643
# Данные добавлены в БД: test_media_costs, таблица: adex_subbrand_list_dict
# Скрипт отработал 2025-04-25 17:06:12.280643
# Время выполнения задачи: 0:00:00
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:12.343779
# Данные добавлены в БД: test_media_costs, таблица: adex_model_list_dict
# Скрипт отработал 2025-04-25 17:06:12.343779
# Время выполнения задачи: 0:00:00
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:12.390921
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list2_dict
# Скрипт отработал 2025-04-25 17:06:12.390921
# Время выполнения задачи: 0:00:00
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:12.437816
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list3_dict
# Скрипт отработал 2025-04-25 17:06:12.453440
# Время выполнения задачи: 0:00:00.015624
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 17:06:12.484754
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list4_dict
# Скрипт отработал 2025-04-25 17:06:12.500384
# Время выполнения задачи: 0:00:00.015630
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################

# %%
# загружаем в гугл докс Чистка список объяалений с флагом=2
query = config_media_costs.google_new_ads_media_invest['query']
worksheet = config_media_costs.google_new_ads_media_invest['worksheet']

append_ads_to_google(query=query, worksheet=worksheet)
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Connection established successfully...
# DataFrame exported successfully...
