# %%
import os

from time import sleep
import config
import config_media_costs
from config_search_funcs import get_subbrand_id_str
from media_costs import get_media_costs_report, get_mon_num_from_date
from create_dicts_adex import create_adex_tables, download_adex_default_dicts, update_media_ads_dict, update_another_dicts, update_list_dicts, create_adex_views
from google_connector import append_ads_to_google


subbrand_id_str = get_subbrand_id_str(mon_num='360')
special_ad_filter = f'{config_media_costs.main_filter_str} AND t10.sbid in ({subbrand_id_str})'

start_date = '2025-02-01' # если дата начала НЕ указана, то start_date = Сегодня минус 3 дня минус 17 дней
end_date = '2025-02-02' #- ВКЛЮЧИТЕЛЬНО / если дата окончания НЕ указана, то end_date = Сегодня минус 3 дня

flag='regular' #first / regular
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно

# %%
# создаем пустые таблицы Фактов и Справочники
# Заполняем справоники по умолчанию данными config_media_costs.adex_defult_dicts
# Company / Ad_type / EState / 
if flag=='first':
    # создаем все пустые таблицы
    create_adex_tables()
    sleep(10)
    # наполняем данными справочники, которые НЕ обновляются
    download_adex_default_dicts()
    sleep(10)
    # создаем Представления
    create_adex_views()

# забираем статистику по каждому Медиа за указанный период
for key, value in config.media_type_dict.items():
    get_media_costs_report(start_date=start_date, end_date=end_date, media_type=key, flag=flag, main_filter=special_ad_filter)
# Out:
# Скрипт запущен 2025-04-25 15:54:49.582811
#
# **************************************************
# Удалем строки из таблицы: media_tv_costs по условию: mon_num >= 421 and mon_num <= 421
#
# Все ок. Подключились!
# Строки с условием WHERE mon_num >= 421 and mon_num <= 421 удалены из Таблицы: media_tv_costs в БД: test_media_costs
# ##########
#
#
# Загружаем отчет за период 2025-02-01 - 2025-02-02. Общее количество месяцев: 1
# **************************************************
#
#
# ==========Загружаем 2025-02-01. Статистика по tv
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:00.667252
# Данные добавлены в БД: test_media_costs, таблица: media_tv_costs
# Скрипт отработал 2025-04-25 15:55:03.113969
# Время выполнения задачи: 0:00:02.446717
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Скрипт запущен 2025-04-25 15:55:03.130970
#
# **************************************************
# Удалем строки из таблицы: media_ra_costs по условию: mon_num >= 421 and mon_num <= 421
#
# Все ок. Подключились!
# Таблицы media_ra_costs не существует в БД test_media_costs
#
#
# Загружаем отчет за период 2025-02-01 - 2025-02-02. Общее количество месяцев: 1
# **************************************************
#
#
# ==========Загружаем 2025-02-01. Статистика по ra
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:05.751049
# Данные добавлены в БД: test_media_costs, таблица: media_radio_costs
# Скрипт отработал 2025-04-25 15:55:05.793040
# Время выполнения задачи: 0:00:00.041991
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Скрипт запущен 2025-04-25 15:55:05.793040
#
# **************************************************
# Удалем строки из таблицы: media_od_costs по условию: mon_num >= 421 and mon_num <= 421
#
# Все ок. Подключились!
# Таблицы media_od_costs не существует в БД test_media_costs
#
#
# Загружаем отчет за период 2025-02-01 - 2025-02-02. Общее количество месяцев: 1
# **************************************************
#
#
# ==========Загружаем 2025-02-01. Статистика по od
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:08.690319
# Данные добавлены в БД: test_media_costs, таблица: media_outdoor_costs
# Скрипт отработал 2025-04-25 15:55:08.772059
# Время выполнения задачи: 0:00:00.081740
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Скрипт запущен 2025-04-25 15:55:08.773059
#
# **************************************************
# Удалем строки из таблицы: media_pr_costs по условию: mon_num >= 421 and mon_num <= 421
#
# Все ок. Подключились!
# Таблицы media_pr_costs не существует в БД test_media_costs
#
#
# Загружаем отчет за период 2025-02-01 - 2025-02-02. Общее количество месяцев: 1
# **************************************************
#
#
# ==========Загружаем 2025-02-01. Статистика по pr
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:11.111934
# Данные добавлены в БД: test_media_costs, таблица: media_press_costs
# Скрипт отработал 2025-04-25 15:55:11.130935
# Время выполнения задачи: 0:00:00.019001
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################

# %%
for media_type, media_type_long in config.media_type_dict.items():
    update_media_ads_dict(media_type)
    update_another_dicts(media_type)
    update_list_dicts(media_type)
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:15.960202
# Данные добавлены в БД: test_media_costs, таблица: adex_ad_dict_list_tv
# Скрипт отработал 2025-04-25 15:55:15.983595
# Время выполнения задачи: 0:00:00.023393
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:16.030893
# Данные добавлены в БД: test_media_costs, таблица: adex_audio_slogan_dict_tv
# Скрипт отработал 2025-04-25 15:55:16.040894
# Время выполнения задачи: 0:00:00.010001
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:16.079907
# Данные добавлены в БД: test_media_costs, таблица: adex_video_slogan_dict_tv
# Скрипт отработал 2025-04-25 15:55:16.089907
# Время выполнения задачи: 0:00:00.010000
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:16.127906
# Данные добавлены в БД: test_media_costs, таблица: adex_advertiser_list_dict
# Скрипт отработал 2025-04-25 15:55:16.138906
# Время выполнения задачи: 0:00:00.011000
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:16.182563
# Данные добавлены в БД: test_media_costs, таблица: adex_brand_list_dict
# Скрипт отработал 2025-04-25 15:55:16.195563
# Время выполнения задачи: 0:00:00.013000
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:16.236243
# Данные добавлены в БД: test_media_costs, таблица: adex_subbrand_list_dict
# Скрипт отработал 2025-04-25 15:55:16.246911
# Время выполнения задачи: 0:00:00.010668
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:16.273792
# Данные добавлены в БД: test_media_costs, таблица: adex_model_list_dict
# Скрипт отработал 2025-04-25 15:55:16.300758
# Время выполнения задачи: 0:00:00.026966
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:16.343842
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list2_dict
# Скрипт отработал 2025-04-25 15:55:16.354842
# Время выполнения задачи: 0:00:00.011000
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:16.391841
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list3_dict
# Скрипт отработал 2025-04-25 15:55:16.411843
# Время выполнения задачи: 0:00:00.020002
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:16.451436
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list4_dict
# Скрипт отработал 2025-04-25 15:55:16.463119
# Время выполнения задачи: 0:00:00.011683
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:21.620810
# Данные добавлены в БД: test_media_costs, таблица: adex_ad_dict_list_radio
# Скрипт отработал 2025-04-25 15:55:21.654373
# Время выполнения задачи: 0:00:00.033563
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:21.699486
# Данные добавлены в БД: test_media_costs, таблица: adex_advertiser_list_dict
# Скрипт отработал 2025-04-25 15:55:21.710486
# Время выполнения задачи: 0:00:00.011000
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:21.745486
# Данные добавлены в БД: test_media_costs, таблица: adex_brand_list_dict
# Скрипт отработал 2025-04-25 15:55:21.758084
# Время выполнения задачи: 0:00:00.012598
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:21.808084
# Данные добавлены в БД: test_media_costs, таблица: adex_subbrand_list_dict
# Скрипт отработал 2025-04-25 15:55:21.819202
# Время выполнения задачи: 0:00:00.011118
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:21.857889
# Данные добавлены в БД: test_media_costs, таблица: adex_model_list_dict
# Скрипт отработал 2025-04-25 15:55:21.869889
# Время выполнения задачи: 0:00:00.012000
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
# Новых ИД НЕТ для загрузки в таблицу adex_article_list2_dict
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:21.919602
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list3_dict
# Скрипт отработал 2025-04-25 15:55:21.941026
# Время выполнения задачи: 0:00:00.021424
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:21.981814
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list4_dict
# Скрипт отработал 2025-04-25 15:55:21.993821
# Время выполнения задачи: 0:00:00.012007
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:24.996015
# Данные добавлены в БД: test_media_costs, таблица: adex_ad_dict_list_outdoor
# Скрипт отработал 2025-04-25 15:55:25.034366
# Время выполнения задачи: 0:00:00.038351
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:25.081603
# Данные добавлены в БД: test_media_costs, таблица: adex_advertiser_list_dict
# Скрипт отработал 2025-04-25 15:55:25.094603
# Время выполнения задачи: 0:00:00.013000
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:25.133293
# Данные добавлены в БД: test_media_costs, таблица: adex_brand_list_dict
# Скрипт отработал 2025-04-25 15:55:25.148998
# Время выполнения задачи: 0:00:00.015705
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:25.196659
# Данные добавлены в БД: test_media_costs, таблица: adex_subbrand_list_dict
# Скрипт отработал 2025-04-25 15:55:25.212659
# Время выполнения задачи: 0:00:00.016000
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:25.261828
# Данные добавлены в БД: test_media_costs, таблица: adex_model_list_dict
# Скрипт отработал 2025-04-25 15:55:25.276844
# Время выполнения задачи: 0:00:00.015016
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:25.311817
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list2_dict
# Скрипт отработал 2025-04-25 15:55:25.330042
# Время выполнения задачи: 0:00:00.018225
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:25.380038
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list3_dict
# Скрипт отработал 2025-04-25 15:55:25.391038
# Время выполнения задачи: 0:00:00.011000
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:25.429053
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list4_dict
# Скрипт отработал 2025-04-25 15:55:25.442510
# Время выполнения задачи: 0:00:00.013457
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:41.168874
# Данные добавлены в БД: test_media_costs, таблица: adex_ad_dict_list_press
# Скрипт отработал 2025-04-25 15:55:41.198875
# Время выполнения задачи: 0:00:00.030001
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:41.245538
# Данные добавлены в БД: test_media_costs, таблица: adex_advertiser_list_dict
# Скрипт отработал 2025-04-25 15:55:41.262108
# Время выполнения задачи: 0:00:00.016570
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:41.308773
# Данные добавлены в БД: test_media_costs, таблица: adex_brand_list_dict
# Скрипт отработал 2025-04-25 15:55:41.322773
# Время выполнения задачи: 0:00:00.014000
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:41.363397
# Данные добавлены в БД: test_media_costs, таблица: adex_subbrand_list_dict
# Скрипт отработал 2025-04-25 15:55:41.381403
# Время выполнения задачи: 0:00:00.018006
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:41.430397
# Данные добавлены в БД: test_media_costs, таблица: adex_model_list_dict
# Скрипт отработал 2025-04-25 15:55:41.445398
# Время выполнения задачи: 0:00:00.015001
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:41.483094
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list2_dict
# Скрипт отработал 2025-04-25 15:55:41.495420
# Время выполнения задачи: 0:00:00.012326
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:41.535093
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list3_dict
# Скрипт отработал 2025-04-25 15:55:41.547978
# Время выполнения задачи: 0:00:00.012885
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:55:41.589729
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list4_dict
# Скрипт отработал 2025-04-25 15:55:41.601730
# Время выполнения задачи: 0:00:00.012001
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################

# %%
# загружаем в гугл докс Чистка список объяалений с флагом=2
query = config_media_costs.google_new_ads_media_invest['query']
worksheet = config_media_costs.google_new_ads_media_invest['worksheet']

append_ads_to_google(query=query, worksheet=worksheet)
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Connection established successfully...
# DataFrame exported successfully...
