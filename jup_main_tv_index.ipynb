# %%
import os

from time import sleep
import config
import config_tv_index
from config_search_funcs import get_subbrand_id_str
from nat_tv_ratings import get_nat_tv_reports
from create_dicts_tv_index import update_tv_index_dicts, update_nat_tv_ad_dict
from google_connector import append_ads_to_google

subbrand_id_str = get_subbrand_id_str(mon_num='360')
special_ad_filter = f'{config_tv_index.nat_tv_ad_filter} AND subbrandId IN ({subbrand_id_str})'

start_date = '2025-01-30' # если дата начала НЕ указана, то start_date = Сегодня минус 3 дня минус 17 дней
end_date = '2025-01-30' #- ВКЛЮЧИТЕЛЬНО / если дата окончания НЕ указана, то end_date = Сегодня минус 3 дня

flag='first' #first / regular
# Out:
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно

# %%
# Если флаг first - создаем набор пустых таблиц-справочников / 
# забираем статистику / заполняем таблицы фактов и справочник nat_tv_ad_dict
# Если флаг regular - то грузим статистику и обновляем справочники
# если start_date(дата начала) НЕ указана, то 
# удаляем из БД - последние 17(сегодня-14-3) дней
# перезаисываем статистику за этот период
# если НЕ указана end_date(дата окончания) - ВКЛЮЧИТЕЛЬНО, то грузим данные до сегодня-3 дня
# получаем статистику по отчету Simple и Buying
get_nat_tv_reports(ad_filter=special_ad_filter, start_date=start_date, end_date=end_date, flag=flag)
# get_nat_tv_reports(flag=flag)
# Обновляем все справочники из ТВ Индекс
update_tv_index_dicts()
# Обновляем основной справочник объявлений
update_nat_tv_ad_dict()

# загружаем в гугл докс Чистка список объяалений с флагом=2
query = config_tv_index.google_new_ads_nat_tv['query']
worksheet = config_tv_index.google_new_ads_nat_tv['worksheet']

append_ads_to_google(query=query, worksheet=worksheet)
# Out:
# Скрипт запущен 2025-04-25 15:58:46.894151
# Все ок. Подключились!
# Пустая таблица nat_tv_simple успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица nat_tv_buying успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица nat_tv_ad_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица tv_index_region_dict успешно создана в БД test_media_costs
# Запрошены записи: 0 - 28
# Всего найдено записей: 28
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:58:47.074316
# Данные добавлены в БД: test_media_costs, таблица: tv_index_region_dict
# Скрипт отработал 2025-04-25 15:58:47.106236
# Время выполнения задачи: 0:00:00.031920
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_tv_net_dict успешно создана в БД test_media_costs
# Запрошены записи: 0 - 44
# Всего найдено записей: 44
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:58:47.178701
# Данные добавлены в БД: test_media_costs, таблица: tv_index_tv_net_dict
# Скрипт отработал 2025-04-25 15:58:47.195053
# Время выполнения задачи: 0:00:00.016352
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_tv_company_dict успешно создана в БД test_media_costs
# Запрошены записи: 0 - 2418
# Всего найдено записей: 2418
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:58:47.476295
# Данные добавлены в БД: test_media_costs, таблица: tv_index_tv_company_dict
# Скрипт отработал 2025-04-25 15:58:47.552179
# Время выполнения задачи: 0:00:00.075884
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_ad_type_dict успешно создана в БД test_media_costs
# Запрошены записи: 0 - 24
# Всего найдено записей: 24
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:58:47.597997
# Данные добавлены в БД: test_media_costs, таблица: tv_index_ad_type_dict
# Скрипт отработал 2025-04-25 15:58:47.613685
# Время выполнения задачи: 0:00:00.015688
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Пустая таблица tv_index_advertiser_list_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица tv_index_brand_list_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица tv_index_subbrand_list_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица tv_index_model_list_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица tv_index_article_list2_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица tv_index_article_list3_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица tv_index_article_list4_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица tv_index_audio_slogan_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица tv_index_video_slogan_dict успешно создана в БД test_media_costs
# **************************************************
# Забираем из БД НЕ ОБНОВЛЕННЫЙ справочник объявлений
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
#
# Загружаем отчет за период 2025-01-30 - 2025-01-30. Общее количество дней: 1
# **************************************************
#
#
# ==========Загружаем 2025-01-30. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: ba03aaa9-65d0-47f5-8003-771aeea38842) [= = = = = = = = = = = ] время расчета: 0:00:34.384032
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 15:59:28.963692
# Данные добавлены в БД: test_media_costs, таблица: nat_tv_buying
# Скрипт отработал 2025-04-25 15:59:29.047339
# Время выполнения задачи: 0:00:00.083647
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (20) [ = = ] время расчета: 0:00:15.295121
# Расчет завершен, получаем результат
# Собираем таблицу
# ....................Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 16:00:44.877820
# Данные добавлены в БД: test_media_costs, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-04-25 16:00:44.896193
# Время выполнения задачи: 0:00:00.018373
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 16:00:44.898536
# Данные добавлены в БД: test_media_costs, таблица: nat_tv_simple
# Скрипт отработал 2025-04-25 16:00:46.193466
# Время выполнения задачи: 0:00:01.294930
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# **************************************************
#
# **************************************************
# Время окончания работы скрипта 2025-04-25 16:00:46.193466
# Период загрузки 2025-01-30 - 2025-01-30. Общее время работы скрипта: 0:01:59.299315
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 13
# Всего найдено записей: 13
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 16:00:46.259812
# Данные добавлены в БД: test_media_costs, таблица: tv_index_advertiser_list_dict
# Скрипт отработал 2025-04-25 16:00:46.273811
# Время выполнения задачи: 0:00:00.013999
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 16
# Всего найдено записей: 16
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 16:00:46.334691
# Данные добавлены в БД: test_media_costs, таблица: tv_index_brand_list_dict
# Скрипт отработал 2025-04-25 16:00:46.348692
# Время выполнения задачи: 0:00:00.014001
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 2
# Всего найдено записей: 2
#
# Запрошены записи: 0 - 17
# Всего найдено записей: 17
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 16:00:46.445318
# Данные добавлены в БД: test_media_costs, таблица: tv_index_subbrand_list_dict
# Скрипт отработал 2025-04-25 16:00:46.466318
# Время выполнения задачи: 0:00:00.021000
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 37
# Всего найдено записей: 37
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 16:00:46.541210
# Данные добавлены в БД: test_media_costs, таблица: tv_index_model_list_dict
# Скрипт отработал 2025-04-25 16:00:46.558784
# Время выполнения задачи: 0:00:00.017574
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 8
# Всего найдено записей: 8
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 16:00:46.620218
# Данные добавлены в БД: test_media_costs, таблица: tv_index_article_list2_dict
# Скрипт отработал 2025-04-25 16:00:46.632216
# Время выполнения задачи: 0:00:00.011998
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 20
# Всего найдено записей: 20
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 16:00:46.686895
# Данные добавлены в БД: test_media_costs, таблица: tv_index_article_list3_dict
# Скрипт отработал 2025-04-25 16:00:46.702532
# Время выполнения задачи: 0:00:00.015637
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 26
# Всего найдено записей: 26
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 16:00:46.763705
# Данные добавлены в БД: test_media_costs, таблица: tv_index_article_list4_dict
# Скрипт отработал 2025-04-25 16:00:46.778578
# Время выполнения задачи: 0:00:00.014873
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 11
# Всего найдено записей: 11
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 16:00:46.839393
# Данные добавлены в БД: test_media_costs, таблица: tv_index_audio_slogan_dict
# Скрипт отработал 2025-04-25 16:00:46.864481
# Время выполнения задачи: 0:00:00.025088
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 10
# Всего найдено записей: 10
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 16:00:46.935199
# Данные добавлены в БД: test_media_costs, таблица: tv_index_video_slogan_dict
# Скрипт отработал 2025-04-25 16:00:46.954198
# Время выполнения задачи: 0:00:00.018999
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: nat_tv_ad_dict успешно удалена в БД: test_media_costs
# ##########
# Все ок. Подключились!
# Пустая таблица nat_tv_ad_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Скрипт запущен 2025-04-25 16:01:04.638951
# Данные добавлены в БД: test_media_costs, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-04-25 16:01:04.671951
# Время выполнения задачи: 0:00:00.033000
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Connection established successfully...
# DataFrame exported successfully...
