# %%
import os

from time import sleep
import config
import config_media_costs
from config_search_funcs import get_subbrand_id_str
from media_costs import get_media_costs_report, get_mon_num_from_date
from create_dicts_adex import create_adex_tables, download_adex_default_dicts, update_media_ads_dict, update_another_dicts, update_list_dicts, create_adex_views


subbrand_id_str = get_subbrand_id_str(mon_num='360')
special_ad_filter = f'{config_media_costs.main_filter_str} AND t10.sbid in ({subbrand_id_str})'

start_date = '2025-01-01' # если дата начала НЕ указана, то start_date = Сегодня минус 3 дня минус 17 дней
end_date = '2025-01-02' #- ВКЛЮЧИТЕЛЬНО / если дата окончания НЕ указана, то end_date = Сегодня минус 3 дня

flag='first' #first / regular
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно

# %%
# создаем пустые таблицы Фактов и Справочники
# Заполняем справоники по умолчанию данными config_media_costs.adex_defult_dicts
# Company / Ad_type / EState / 
if flag=='first':
    # создаем все пустые таблицы
    create_adex_tables()
    sleep(10)
    # наполняем данными справочники, которые НЕ обновляются
    download_adex_default_dicts()
    sleep(10)
    # создаем Представления
    create_adex_views()

# забираем статистику по каждому Медиа за указанный период
for key, value in config.media_type_dict.items():
    get_media_costs_report(start_date=start_date, end_date=end_date, media_type=key, flag=flag, main_filter=special_ad_filter)
# Out:
# Все ок. Подключились!
# Пустая таблица adex_distribution_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_estate_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_regions_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица media_tv_costs успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_company_dict_tv успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_tv успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_audio_slogan_dict_tv успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_video_slogan_dict_tv успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_tv успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица media_radio_costs успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_company_dict_radio успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_radio успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_radio успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица media_press_costs успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_company_dict_press успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_press успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_press успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица media_outdoor_costs успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_company_dict_outdoor успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_ad_type_dict_outdoor успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_network_dict_outdoor успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_ad_dict_list_outdoor успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_advertiser_list_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_brand_list_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_subbrand_list_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_model_list_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_article_list2_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_article_list3_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Пустая таблица adex_article_list4_dict успешно создана в БД test_media_costs
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-24 19:40:40.169309
# Данные добавлены в БД: test_media_costs, таблица: adex_distribution_dict
# Скрипт отработал 2025-04-24 19:40:40.182341
# Время выполнения задачи: 0:00:00.013032
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-24 19:40:40.188758
# Данные добавлены в БД: test_media_costs, таблица: adex_estate_dict
# Скрипт отработал 2025-04-24 19:40:40.199706
# Время выполнения задачи: 0:00:00.010948
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-24 19:40:40.207918
# Данные добавлены в БД: test_media_costs, таблица: adex_regions_dict
# Скрипт отработал 2025-04-24 19:40:40.222664
# Время выполнения задачи: 0:00:00.014746
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-24 19:40:40.283819
# Данные добавлены в БД: test_media_costs, таблица: adex_company_dict_outdoor
# Скрипт отработал 2025-04-24 19:40:40.439982
# Время выполнения задачи: 0:00:00.156163
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-24 19:40:40.450246
# Данные добавлены в БД: test_media_costs, таблица: adex_ad_type_dict_outdoor
# Скрипт отработал 2025-04-24 19:40:40.463207
# Время выполнения задачи: 0:00:00.012961
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-24 19:40:40.481065
# Данные добавлены в БД: test_media_costs, таблица: adex_network_dict_outdoor
# Скрипт отработал 2025-04-24 19:40:40.525994
# Время выполнения задачи: 0:00:00.044929
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Ошибка при создании Представления в БД test_media_costs
# Все ок. Подключились!
# Ошибка при создании Представления в БД test_media_costs
# Все ок. Подключились!
# Ошибка при создании Представления в БД test_media_costs
# Скрипт запущен 2025-04-24 19:40:50.538144
#
# Загружаем отчет за период 2025-01-01 - 2025-01-02. Общее количество месяцев: 1
# **************************************************
#
#
# ==========Загружаем 2025-01-01. Статистика по od
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-24 19:40:55.246499
# Данные добавлены в БД: test_media_costs, таблица: media_outdoor_costs
# Скрипт отработал 2025-04-24 19:40:56.519140
# Время выполнения задачи: 0:00:01.272641
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################

# %%
for media_type, media_type_long in config.media_type_dict.items():
    update_media_ads_dict(media_type)
    update_another_dicts(media_type)
    update_list_dicts(media_type)
# Out:
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-24 19:41:10.012030
# Данные добавлены в БД: test_media_costs, таблица: adex_ad_dict_list_outdoor
# Скрипт отработал 2025-04-24 19:41:10.532100
# Время выполнения задачи: 0:00:00.520070
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-24 19:41:11.448312
# Данные добавлены в БД: test_media_costs, таблица: adex_advertiser_list_dict
# Скрипт отработал 2025-04-24 19:41:11.662438
# Время выполнения задачи: 0:00:00.214126
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-24 19:41:12.883420
# Данные добавлены в БД: test_media_costs, таблица: adex_brand_list_dict
# Скрипт отработал 2025-04-24 19:41:13.228419
# Время выполнения задачи: 0:00:00.344999
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-24 19:41:14.470746
# Данные добавлены в БД: test_media_costs, таблица: adex_subbrand_list_dict
# Скрипт отработал 2025-04-24 19:41:14.763074
# Время выполнения задачи: 0:00:00.292328
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-24 19:41:16.301850
# Данные добавлены в БД: test_media_costs, таблица: adex_model_list_dict
# Скрипт отработал 2025-04-24 19:41:16.672389
# Время выполнения задачи: 0:00:00.370539
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-24 19:41:16.778051
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list2_dict
# Скрипт отработал 2025-04-24 19:41:16.808050
# Время выполнения задачи: 0:00:00.029999
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-24 19:41:16.953732
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list3_dict
# Скрипт отработал 2025-04-24 19:41:16.987392
# Время выполнения задачи: 0:00:00.033660
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Скрипт запущен 2025-04-24 19:41:17.125002
# Данные добавлены в БД: test_media_costs, таблица: adex_article_list4_dict
# Скрипт отработал 2025-04-24 19:41:17.182000
# Время выполнения задачи: 0:00:00.056998
# Загрузка завершена. Данные успешно добавлены в БД: test_media_costs
# ##################################################
