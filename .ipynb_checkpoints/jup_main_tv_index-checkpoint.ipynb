# %%
import os

from time import sleep
import config
import config_tv_index
from config_search_funcs import get_subbrand_id_str
from nat_tv_ratings import get_nat_tv_reports
from create_dicts_tv_index import update_tv_index_dicts, update_nat_tv_ad_dict
from google_connector import append_ads_to_google

subbrand_id_str = get_subbrand_id_str(mon_num='360', media_type='tv')
special_ad_filter = f'{config_tv_index.nat_tv_ad_filter} AND subbrandId IN ({subbrand_id_str})'

start_date = '2025-03-01' # если дата начала НЕ указана, то start_date = Сегодня минус 3 дня минус 17 дней
end_date = '2025-03-02' #- ВКЛЮЧИТЕЛЬНО / если дата окончания НЕ указана, то end_date = Сегодня минус 3 дня

flag='regular' #first / regular
# Out:
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Все ок. Подключились!
# Загрузка завершена успешно

# %%
# Если флаг first - создаем набор пустых таблиц-справочников / 
# забираем статистику / заполняем таблицы фактов и справочник nat_tv_ad_dict
# Если флаг regular - то грузим статистику и обновляем справочники
# если start_date(дата начала) НЕ указана, то 
# удаляем из БД - последние 17(сегодня-14-3) дней
# перезаисываем статистику за этот период
# если НЕ указана end_date(дата окончания) - ВКЛЮЧИТЕЛЬНО, то грузим данные до сегодня-3 дня
# получаем статистику по отчету Simple и Buying
get_nat_tv_reports(ad_filter=special_ad_filter, start_date=start_date, end_date=end_date, flag=flag)
# get_nat_tv_reports(flag=flag)
# Обновляем все справочники из ТВ Индекс
update_tv_index_dicts()
# Обновляем основной справочник объявлений
update_nat_tv_ad_dict()

# загружаем в гугл докс Чистка список объяалений с флагом=2
append_ads_to_google()
# Out:
# Скрипт запущен 2025-04-15 09:31:31.963577
# **************************************************
# Забираем из БД НЕ ОБНОВЛЕННЫЙ справочник объявлений
# Все ок. Подключились!
# Загрузка завершена успешно
# **************************************************
#
# **************************************************
# Удалем строки из таблицы: nat_tv_simple и nat_tv_buying по условию: researchDate >= '2025-03-01' and researchDate <= '2025-03-02'
#
# Все ок. Подключились!
# Строки с условием WHERE researchDate >= '2025-03-01' and researchDate <= '2025-03-02' удалены из Таблицы: nat_tv_simple в БД: mediascope_dbbs_alfa
# ##########
# Все ок. Подключились!
# Строки с условием WHERE researchDate >= '2025-03-01' and researchDate <= '2025-03-02' удалены из Таблицы: nat_tv_buying в БД: mediascope_dbbs_alfa
# ##########
#
#
# Загружаем отчет за период 2025-03-01 - 2025-03-02. Общее количество дней: 2
# **************************************************
#
#
# ==========Загружаем 2025-03-01. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: 6584400a-ae2e-4c0d-86f0-ab95d429bb82) [= = = = = = = = ] время расчета: 0:00:25.515133
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-15 09:32:05.282923
# Данные добавлены в БД: mediascope_dbbs_alfa, таблица: nat_tv_buying
# Скрипт отработал 2025-04-15 09:32:05.427036
# Время выполнения задачи: 0:00:00.144113
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_dbbs_alfa
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (19) [ = = = ] время расчета: 0:00:23.732405
# Расчет завершен, получаем результат
# Собираем таблицу
# ...................Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-15 09:33:25.565735
# Данные добавлены в БД: mediascope_dbbs_alfa, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-04-15 09:33:25.581359
# Время выполнения задачи: 0:00:00.015624
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_dbbs_alfa
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-15 09:33:25.596985
# Данные добавлены в БД: mediascope_dbbs_alfa, таблица: nat_tv_simple
# Скрипт отработал 2025-04-15 09:33:27.573359
# Время выполнения задачи: 0:00:01.976374
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_dbbs_alfa
# ##################################################
#
# **************************************************
#
#
# ==========Загружаем 2025-03-02. Отправляем задания на расчет
#
# -------------------- Забираем статистику по отчету Buying
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Расчет задачи (id: bc405ec1-26de-470d-96de-3e08e2918b59) [= = = = = = = = ] время расчета: 0:00:25.541243
# Записываем данные в таблицу фактов Buying
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-15 09:33:59.754937
# Данные добавлены в БД: mediascope_dbbs_alfa, таблица: nat_tv_buying
# Скрипт отработал 2025-04-15 09:33:59.879875
# Время выполнения задачи: 0:00:00.124938
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_dbbs_alfa
# ##################################################
#
#
# **************************************************
#
# -------------------- Забираем статистику по отчету Simple
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
# Запрошены записи: 0 - 314
# Всего найдено записей: 314
#
#
# Ждем выполнения
# Расчет задач (19) [ = = = ] время расчета: 0:00:23.227993
# Расчет завершен, получаем результат
# Собираем таблицу
# ...................Все ок. Подключились!
# Загрузка завершена успешно
#
# **************************************************
# Записываем данные в справочник объявлений TV_Index
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-15 09:35:19.680153
# Данные добавлены в БД: mediascope_dbbs_alfa, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-04-15 09:35:19.711321
# Время выполнения задачи: 0:00:00.031168
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_dbbs_alfa
# ##################################################
#
# **************************************************
#
# Записываем данные в таблицу фактов Simple
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-15 09:35:19.727011
# Данные добавлены в БД: mediascope_dbbs_alfa, таблица: nat_tv_simple
# Скрипт отработал 2025-04-15 09:35:21.764615
# Время выполнения задачи: 0:00:02.037604
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_dbbs_alfa
# ##################################################
#
# **************************************************
#
# **************************************************
# Время окончания работы скрипта 2025-04-15 09:35:21.764615
# Период загрузки 2025-03-01 - 2025-03-02. Общее время работы скрипта: 0:03:49.801038
# **************************************************
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Запрошены записи: 0 - 1
# Всего найдено записей: 1
#
# Все ок. Подключились!
# Скрипт запущен 2025-04-15 09:35:22.175764
# Данные добавлены в БД: mediascope_dbbs_alfa, таблица: tv_index_model_list_dict
# Скрипт отработал 2025-04-15 09:35:22.191410
# Время выполнения задачи: 0:00:00.015646
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_dbbs_alfa
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Загрузка завершена успешно
# Все ок. Подключились!
# Таблица: nat_tv_ad_dict успешно удалена в БД: mediascope_dbbs_alfa
# ##########
# Все ок. Подключились!
# Пустая таблица nat_tv_ad_dict успешно создана в БД mediascope_dbbs_alfa
# Все ок. Подключились!
# Скрипт запущен 2025-04-15 09:35:29.983308
# Данные добавлены в БД: mediascope_dbbs_alfa, таблица: nat_tv_ad_dict
# Скрипт отработал 2025-04-15 09:35:30.045743
# Время выполнения задачи: 0:00:00.062435
# Загрузка завершена. Данные успешно добавлены в БД: mediascope_dbbs_alfa
# ##################################################
#
# Все ок. Подключились!
# Загрузка завершена успешно
# Connection established successfully...
# DataFrame exported successfully...
